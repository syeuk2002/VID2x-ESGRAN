# %% [markdown]
# <a href="https://colab.research.google.com/github/syeuk2002/VID2x-ESGRAN/blob/master/FILM_Interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FILM Colab
# ### More information about **frame-interpolation** algorithm on [github](https://github.com/google-research/frame-interpolation)
# ---
# ###telegram: [тоже моушн](https://t.me/too_motion)
#
# Stronger GDrive integration and other minor modifications by [Derrick Schultz](https://linktr.ee/dvsmethid).
#
# If you have Pro/+, I highly recommend using the High RAM setting.

# %%
#@title ##Mount Google Drive
import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/MyDrive
HOME='/content/gdrive/MyDrive'
# !nvidia-smi
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive
# Sat Dec  3 15:55:41 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#@title ##Clone the frame-interpolation source code from `github.com/google-research`
if not os.path.isdir(f'{HOME}/frame-interpolation'):
  # !git clone https://github.com/google-research/frame-interpolation
# %cd frame-interpolation
# Out:
# Cloning into 'frame-interpolation'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 230 (delta 95), reused 65 (delta 51), pack-reused 94
# Receiving objects: 100% (230/230), 27.00 MiB | 20.58 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# /content/gdrive/MyDrive/frame-interpolation

# %%
#@title ##Install FILM, download pretrained_models from `google-drive`
# !pip install -r requirements.txt
if not os.path.isdir(f'{HOME}/frame-interpolation/pretrained_models'):
  # !gdown 1C1YwOo293_yrgSS8tAyFbbVcMeXxzftE -O pretrained_models-20220214T214839Z-001.zip
  # !unzip -o "pretrained_models-20220214T214839Z-001.zip"
  # !rm -rf pretrained_models-20220214T214839Z-001.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 458.4 MB 32 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 98.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 77.4 MB/s
# ...
#      |████████████████████████████████| 129 kB 104.6 MB/s
# ...
#      |████████████████████████████████| 13.8 MB 15.8 MB/s
# ...
#      |████████████████████████████████| 11.7 MB 29.0 MB/s
# ...
#      |████████████████████████████████| 135 kB 86.8 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 65.2 MB/s
# ...
#      |████████████████████████████████| 462 kB 62.9 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 27.8 MB/s
# ...
#      |████████████████████████████████| 14.9 MB 62.6 MB/s
# ...
#      |████████████████████████████████| 2.7 MB 57.9 MB/s
# ...
#      |████████████████████████████████| 829 kB 77.0 MB/s
# ...
#      |████████████████████████████████| 151 kB 79.4 MB/s
# ...
#      |████████████████████████████████| 278 kB 78.7 MB/s
# ...

# %%
#@markdown ##Run the FILM interpolator
#@markdown The `input_folder` is the fullpath of the input frames to interpolate.
#@markdown In this example it points to the "photos" folder in the cloned repo.

input_folder = '/content/gdrive/MyDrive/frame-interpolation/photos' #@param {type:"string"}
recursion_times = 6 #@param {type:"slider", min:1, max:10, step:1}

model_path = 'pretrained_models/film_net/Style/saved_model'
# !python3 -m eval.interpolator_cli \
   --pattern $input_folder \
   --model_path $model_path \
   --times_to_interpolate $recursion_times \
   --output_video
#@markdown Interpolated frames will be saved at `${input_folder}/interpolated_frames`
#@markdown and the output video will be at `${input_folder}/interpolated.mp4`

# %%
#@title ## Show interpolated video.
import mediapy as media
video = media.read_video('photos/interpolated.mp4')
media.show_video(video, fps=30)
